# %%
import pandas as pd
import seaborn as sns
import nltk
import string
import re
import matplotlib.pyplot as plt
from sklearn import preprocessing
from nltk import word_tokenize 
from nltk.corpus import stopwords

nltk.download("stopwords")
nltk.download('punkt')

palette=sns.color_palette('magma')
sns.set(palette=palette)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\iqbal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\iqbal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv("../Scrapping/Data Fix.csv")
df.head()
# Out:
#                                             reviewId          userName  \
# 0  gp:AOqpTOEnUbk_19-MO6sPHl7z9Z5Dvv2zmmd5NY5Tcm8...       Della Nis94
# 1  gp:AOqpTOE-i_4JaevUcEqVHqOGXjj_JLsRO35lZeEgJU4...    Jakarta Review
# 2  gp:AOqpTOEpoOwOrsQPdu95u3g2IOcGGWUuurm70hWbqXs...       Shasha Rose
# 3  gp:AOqpTOGVbFw4LlhptIBTpsK1oThh1a_AwdKaxfaSvQX...  Kris Panji Mukti
# 4  gp:AOqpTOH7dBxQ2t4OLHM5M0pP4h-_vbwOX5xPK-SA2Lu...       Dwi Wiharti
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                               review  rating             date  \
# 0  Waktu blm di upgrade ataupun udah upgrage sama...       1   5/19/2022 7:37
# 1  Kirim kode verifikasi email gak masuk2 sampe s...       1  4/20/2022 10:01
# 2  saya minta verifikasi sampe 3 kali gagal. teru...       2    4/7/2022 5:04
# 3  Tolong perbaiki masalah untuk pendaftaran vaks...       3   4/4/2022 22:29
# 4  Saya sudah daftar untuk vaksin booster moderna...       1   5/14/2022 7:28
#
#                                          replyReview        repliedAt  \
# 0  Hi kak, mohon maaf atas ketidaknyamanannya. Mo...  5/20/2022 16:50
# 1  Hi kak, mohon maaf atas ketidaknyamanannya. Mo...  4/20/2022 14:37
# 2  Hi kak, mohon maaf atas ketidaknyamanannya. Mo...   4/7/2022 15:34
# 3  Hi kak, mohon maaf atas ketidaknyamanannya. Mo...   4/5/2022 10:51
# 4  Hi kak, mohon maaf atas ketidaknyamanannya. Mo...  5/18/2022 13:47
#
#               Source  Sentimen
# 0  Google Play Store  Negative
# 1  Google Play Store  Negative
# 2  Google Play Store  Negative
# 3  Google Play Store  Negative
# 4  Google Play Store  Negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2222 entries, 0 to 2221
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   reviewId     2080 non-null   object
#  1   userName     2222 non-null   object
#  2   userImage    2080 non-null   object
#  3   review       2222 non-null   object
#  4   rating       2222 non-null   int64
#  5   date         2222 non-null   object
#  6   replyReview  1947 non-null   object
#  7   repliedAt    1817 non-null   object
#  8   Source       2222 non-null   object
#  9   Sentimen     2222 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 173.7+ KB

# %%
dateYear = pd.DatetimeIndex(df['date']).year

# %%
# Visualisasi perbandingan jumlah source review

plt.style.use("seaborn")
plt.title("Grafik perbandingan jumlah source review")
sns.countplot(x="Source", hue="Source", data=df, palette=palette)
plt.figure(figsize=(10, 10))
plt.show()

# %%
# Visualisasi perbandingan jumlah sentiment

plt.style.use("seaborn")
plt.title("Grafik perbandingan jumlah sentiment")
sns.countplot(x="Sentimen", hue="Sentimen", data=df, palette=palette)
plt.figure(figsize=(10, 10))
plt.show()

# %% [markdown]
# # Data Preparation

# %%
# Menghapus kolom yang tidak akan digunakan

df.drop(["reviewId"], axis=1, inplace=True)
df.drop(["userImage"], axis=1, inplace=True)
df.drop(["rating"], axis=1, inplace=True)
df.drop(["date"], axis=1, inplace=True)
df.drop(["replyReview"], axis=1, inplace=True)
df.drop(["repliedAt"], axis=1, inplace=True)
df.drop(["Source"], axis=1, inplace=True)

df.head()
# Out:
#            userName                                             review  \
# 0       Della Nis94  Waktu blm di upgrade ataupun udah upgrage sama...
# 1    Jakarta Review  Kirim kode verifikasi email gak masuk2 sampe s...
# 2       Shasha Rose  saya minta verifikasi sampe 3 kali gagal. teru...
# 3  Kris Panji Mukti  Tolong perbaiki masalah untuk pendaftaran vaks...
# 4       Dwi Wiharti  Saya sudah daftar untuk vaksin booster moderna...
#
#    Sentimen
# 0  Negative
# 1  Negative
# 2  Negative
# 3  Negative
# 4  Negative

# %%
# Konversi data kategorik menjadi data numerik

label_encoder = preprocessing.LabelEncoder()
df['Sentimen']= label_encoder.fit_transform(df['Sentimen'])

# %%
df.head(100)
# Out:
#               userName                                             review  \
# 0          Della Nis94  Waktu blm di upgrade ataupun udah upgrage sama...
# 1       Jakarta Review  Kirim kode verifikasi email gak masuk2 sampe s...
# 2          Shasha Rose  saya minta verifikasi sampe 3 kali gagal. teru...
# 3     Kris Panji Mukti  Tolong perbaiki masalah untuk pendaftaran vaks...
# 4          Dwi Wiharti  Saya sudah daftar untuk vaksin booster moderna...
# ..                 ...                                                ...
# 95         Fini Husnul                          Aplikasi yang sangat baik
# 96  Laura Kastaningrum  Sebetulnya banyak info yang bagus di aplikasi ...
# 97      fhmy milanisti  Mohon tambahkan untuk pembayaran pajak via onl...
# 98      Ambar Diantoro  Terimakasih kasih Jaki, Saya dan keluarga sang...
# 99       Setyawan Aman  Penanggulangan laporan parkir di jalan umum ka...
#
#     Sentimen
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 95         2
# 96         2
# 97         1
# 98         2
# 99         1
#
# [100 rows x 3 columns]

# %% [markdown]
# # Data preprocessing

# %%
# 1. Case Folding -> Mengubah text menjadi format yang sama

df["review"] = df["review"].str.lower()
df.head()
# Out:
#            userName                                             review  \
# 0       Della Nis94  waktu blm di upgrade ataupun udah upgrage sama...
# 1    Jakarta Review  kirim kode verifikasi email gak masuk2 sampe s...
# 2       Shasha Rose  saya minta verifikasi sampe 3 kali gagal. teru...
# 3  Kris Panji Mukti  tolong perbaiki masalah untuk pendaftaran vaks...
# 4       Dwi Wiharti  saya sudah daftar untuk vaksin booster moderna...
#
#    Sentimen
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# 2. Cleansing

def cleansing_text(text):
    # menghapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus URL
    text = text.replace("http://", " ").replace("https://", " ")
    # menghapus punctuation
    text = text.translate(str.maketrans("","",string.punctuation))
    # menghapus single char
    text = re.sub(r"\b[a-zA-Z]\b", " ", text)
    # menghapus number
    text = re.sub(r"\d+", " ", text)

    return text

# %%
df['review'] = df['review'].apply(cleansing_text)

df
# Out:
#               userName                                             review  \
# 0          Della Nis94  waktu blm di upgrade ataupun udah upgrage sama...
# 1       Jakarta Review  kirim kode verifikasi email gak masuk  sampe s...
# 2          Shasha Rose  saya minta verifikasi sampe   kali gagal terus...
# 3     Kris Panji Mukti  tolong perbaiki masalah untuk pendaftaran vaks...
# 4          Dwi Wiharti  saya sudah daftar untuk vaksin booster moderna...
# ...                ...                                                ...
# 2217       123..45..67  ga bisa download sppt pbb dibilang nik salah u...
# 2218        Suryono888                       abis di update ga bisa lapor
# 2219         rirenur30  aplikasi cepat tanggap semoga pelayanan nya ma...
# 2220       Aserehehehe  jaki keren tinggal tambahin rute moda transpor...
# 2221     rezanaipospos  ide nya ud bgus tp fiturnya parah amat cuma ng...
#
#       Sentimen
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2217         0
# 2218         0
# 2219         2
# 2220         2
# 2221         0
#
# [2222 rows x 3 columns]

# %%
#3. Tokenisasi 
def word_tokenize(text):
    return word_tokenize(text)

# %%
df['review_tokenize'] = df['review'].apply(word_tokenize)

df.head()

# %%
#4. Stop word removal
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)

# %%
def stopwords_removal(text):
    return [word for word in text if word not in stopwords]

df["review_stopwords"] = df["review_tokenize"].apply(stopwords_removal)
df.head()
